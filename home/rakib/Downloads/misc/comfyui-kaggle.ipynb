# %%
# %cd /kaggle/working

# !git -C ComfyUI pull || git clone --depth 1 https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI

# !echo "Installing dependencies..."
# !pip install -q -r requirements.txt pyngrok xformers==0.0.21.dev560 torch==2.0.1+cu118 torchvision==0.15.2+cu118 --extra-index-url https://download.pytorch.org/whl/cu118
# !echo "Done"

from pyngrok import ngrok
ngrok.set_auth_token('2SBhQrZelsr5UG3mLmYir9j3gZG_88BwrmiUzzCFFkj1wAsky')
tunnel = ngrok.connect(8188)
print("Open ComfyUI:", tunnel.public_url)

# !python main.py --dont-print-server

# %%
# %cd /kaggle/working/ComfyUI
# !cd custom_nodes && git clone https://github.com/LucianoCirino/efficiency-nodes-comfyui
# %cd /kaggle/working/ComfyUI/models
# !wget https://civitai.com/api/download/models/66043 -O checkpoints/anylora.safetensors
